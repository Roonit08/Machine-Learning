# %% [markdown]
# # Data Analysis with Python using Forbes 2022 Dataset

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets 2/datasets/forbes_2022_billionaires.csv")

# %%
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# 1                Technology                   Amazon  United States
# 2          Fashion & Retail                     LVMH         France
# 3                Technology                Microsoft  United States
# 4     Finance & Investments       Berkshire Hathaway  United States
# ...                     ...                      ...            ...
# 2663          Manufacturing               Fiberglass          China
# 2664             Technology               Navigation          China
# 2665          Manufacturing                chemicals          China
# 2666                 Energy  liquefied petroleum gas          China
# 2667          Manufacturing                polyester          China
#
#            state  ...                      organization selfMade gender  \
# 0          Texas  ...                             Tesla     True      M
# 1     Washington  ...                            Amazon     True      M
# 2            NaN  ...  LVMH Moët Hennessy Louis Vuitton    False      M
# 3     Washington  ...   Bill & Melinda Gates Foundation     True      M
# 4       Nebraska  ...                Berkshire Hathaway     True      M
# ...          ...  ...                               ...      ...    ...
# 2663         NaN  ...                               NaN     True      M
# 2664         NaN  ...                               NaN     True      M
# 2665         NaN  ...                               NaN     True      M
# 2666         NaN  ...                               NaN     True      F
# 2667         NaN  ...                               NaN     True      M
#
#        birthDate             title philanthropyScore  \
# 0     1971-06-28               CEO               1.0
# 1     1964-01-12      Entrepreneur               1.0
# 2     1949-03-05  Chairman and CEO               NaN
# 3     1955-10-28         Cofounder               4.0
# 4     1930-08-30               CEO               5.0
# ...          ...               ...               ...
# 2663  1955-09-01               NaN               NaN
# 2664  1963-03-01               NaN               NaN
# 2665  1965-03-06               NaN               NaN
# 2666  1978-07-11               NaN               NaN
# 2667  1962-06-15               NaN               NaN
#
#                      residenceMsa  numberOfSiblings  \
# 0                             NaN               NaN
# 1     Seattle-Tacoma-Bellevue, WA               NaN
# 2                             NaN               NaN
# 3     Seattle-Tacoma-Bellevue, WA               NaN
# 4                       Omaha, NE               NaN
# ...                           ...               ...
# 2663                          NaN               NaN
# 2664                          NaN               NaN
# 2665                          NaN               NaN
# 2666                          NaN               NaN
# 2667                          NaN               NaN
#
#                                                     bio  \
# 0     Elon Musk is working to revolutionize transpor...
# 1     Jeff Bezos founded e-commerce giant Amazon in ...
# 2     Bernard Arnault oversees the LVMH empire of so...
# 3     Bill Gates turned his fortune from software fi...
# 4     Known as the "Oracle of Omaha," Warren Buffett...
# ...                                                 ...
# 2663  Zhang Yuqiang chairs Zhenshi Holding Group, a ...
# 2664  Zhou Ruxin chairs Beijing BDStar Navigation, a...
# 2665  Zhou Wen chairs Shanghai Pret Composites, a su...
# 2666  Zhou Yifeng chairs Shenzhen-listed Oriental En...
# 2667  Zhuang Kuilong chairs Xinfengming Group, a man...
#
#                                                   about
# 0     Musk was accepted to a graduate program at Sta...
# 1     Growing up, Jeff Bezos worked summers on his g...
# 2     Arnault apparently wooed his wife, Helene Merc...
# 3     When Gates was a kid, he spent so much time re...
# 4     Buffett still lives in the same Omaha, Nebrask...
# ...                                                 ...
# 2663                                                NaN
# 2664                                                NaN
# 2665                                                NaN
# 2666                                                NaN
# 2667                                                NaN
#
# [2668 rows x 22 columns]

# %%
df.describe()
# Out:
#               rank          age     finalWorth    year   month  \
# count  2668.000000  2582.000000    2668.000000  2668.0  2668.0
# mean   1302.919040    64.210689    4762.350075  2022.0     4.0
# std     747.807782    13.401258   10540.482258     0.0     0.0
# min       1.000000    19.000000    1000.000000  2022.0     4.0
# 25%     665.000000    55.000000    1500.000000  2022.0     4.0
# 50%    1292.000000    64.000000    2400.000000  2022.0     4.0
# 75%    1929.000000    74.000000    4300.000000  2022.0     4.0
# max    2578.000000   100.000000  219000.000000  2022.0     4.0
#
#        philanthropyScore  numberOfSiblings
# count         396.000000        127.000000
# mean            1.856061          2.732283
# std             0.971486          1.891706
# min             1.000000          1.000000
# 25%             1.000000          2.000000
# 50%             2.000000          2.000000
# 75%             2.000000          3.000000
# max             5.000000         14.000000

# %%
df.shape
# Out:
# (2668, 22)

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='str')

# %% [markdown]
# ## Data Preprocessing

# %%
df = df.loc[:,["rank","personName","age","finalWorth","category","country","gender"]]

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth               category  \
# 0     1                 Elon Musk  50.0    219000.0             Automotive
# 1     2                Jeff Bezos  58.0    171000.0             Technology
# 2     3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3     4                Bill Gates  66.0    129000.0             Technology
# 4     5            Warren Buffett  91.0    118000.0  Finance & Investments
#
#          country gender
# 0  United States      M
# 1  United States      M
# 2         France      M
# 3  United States      M
# 4  United States      M

# %%
df
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0    219000.0             Automotive
# 1        2                Jeff Bezos  58.0    171000.0             Technology
# 2        3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3        4                Bill Gates  66.0    129000.0             Technology
# 4        5            Warren Buffett  91.0    118000.0  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0          Manufacturing
# 2664  2578                Zhou Ruxin  59.0      1000.0             Technology
# 2665  2578         Wen Zhou & family  57.0      1000.0          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0      1000.0                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0          Manufacturing
#
#             country gender
# 0     United States      M
# 1     United States      M
# 2            France      M
# 3     United States      M
# 4     United States      M
# ...             ...    ...
# 2663          China      M
# 2664          China      M
# 2665          China      M
# 2666          China      F
# 2667          China      M
#
# [2668 rows x 7 columns]

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\RONIT\.conda\envs\anaconda\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# df=df.rename(columns={"rank":"Sıra","personName":"İsim","age":"Yaş",
#                       "finalWorth":"Servet","category":"Kategori",
#                        "country":"Ülke", "gender":"Cinsiyet"})

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth               category  \
# 0     1                 Elon Musk  50.0    219000.0             Automotive
# 1     2                Jeff Bezos  58.0    171000.0             Technology
# 2     3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3     4                Bill Gates  66.0    129000.0             Technology
# 4     5            Warren Buffett  91.0    118000.0  Finance & Investments
#
#          country gender
# 0  United States      M
# 1  United States      M
# 2         France      M
# 3  United States      M
# 4  United States      M

# %%
df = df.set_index("rank")

# %%
df.head()
# Out:
#                     personName   age  finalWorth               category  \
# rank
# 1                    Elon Musk  50.0    219000.0             Automotive
# 2                   Jeff Bezos  58.0    171000.0             Technology
# 3     Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 4                   Bill Gates  66.0    129000.0             Technology
# 5               Warren Buffett  91.0    118000.0  Finance & Investments
#
#             country gender
# rank
# 1     United States      M
# 2     United States      M
# 3            France      M
# 4     United States      M
# 5     United States      M

# %%
df.dtypes
# Out:
# personName        str
# age           float64
# finalWorth    float64
# category          str
# country           str
# gender            str
# dtype: object

# %%
df.isnull().sum()
# Out:
# personName     0
# age           86
# finalWorth     0
# category       0
# country       13
# gender        16
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2568, 6)

# %% [markdown]
# ## Informations about gender of the richest in the world

# %%
df["gender"].value_counts()
# Out:
# gender
# M    2282
# F     286
# Name: count, dtype: int64

# %%
df["gender"].value_counts(normalize=True)
# Out:
# gender
# M    0.888629
# F    0.111371
# Name: proportion, dtype: float64

# %%
df[df["country"]=="Turkey"].gender.value_counts(normalize=True)
# Out:
# gender
# M    0.826087
# F    0.173913
# Name: proportion, dtype: float64

# %%
df["country"].unique()
# Out:
# <StringArray>
# [           'United States',                   'France',
#                     'India',                   'Mexico',
#                     'China',                'Singapore',
#                     'Spain',                   'Canada',
#                   'Germany',              'Switzerland',
#                   'Belgium',                'Hong Kong',
#            'United Kingdom',                'Australia',
#                   'Austria',                    'Italy',
#                     'Japan',                  'Bahamas',
#                 'Indonesia',                    'Chile',
#                    'Russia',                   'Sweden',
#                   'Czechia',                   'Monaco',
#      'United Arab Emirates',                  'Nigeria',
#                   'Denmark',                 'Thailand',
#                  'Malaysia',                   'Brazil',
#                  'Colombia',              'New Zealand',
#               'South Korea',             'South Africa',
#               'Philippines',                    'Egypt',
#                    'Taiwan',                   'Israel',
#                   'Vietnam',                   'Poland',
#                    'Norway',           'Cayman Islands',
#               'Netherlands',     'Eswatini (Swaziland)',
#                      'Peru',                  'Algeria',
#                'Kazakhstan',                  'Georgia',
#                  'Portugal',   'British Virgin Islands',
#                    'Turkey',                  'Finland',
#                   'Ukraine',                  'Ireland',
#                   'Bermuda',                  'Lebanon',
#                 'Argentina',                 'Cambodia',
#                      'Oman',                 'Guernsey',
#             'Liechtenstein', 'Turks and Caicos Islands',
#                     'Qatar',                  'Morocco',
#                   'Uruguay',                 'Slovakia',
#                   'Romania',                    'Nepal',
#                  'Tanzania',                  'Bahrain',
#                    'Greece',                  'Hungary',
#                   'Andorra']
# Length: 73, dtype: str

# %%
df[df["country"]=="Canada"].gender.value_counts(normalize=True)
# Out:
# gender
# M    0.952381
# F    0.047619
# Name: proportion, dtype: float64

# %%
df_gender = df.groupby(["gender"])

# %%
df_gender["age"].mean()
# Out:
# gender
# F    62.937063
# M    64.409290
# Name: age, dtype: float64

# %% [markdown]
# ## Who are the top 10 richest in the world?

# %%
import seaborn as sns
sns.barplot(y = df["personName"][:10], x = df["finalWorth"][:10])
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %% [markdown]
# ## Which country has the highest number of billionaires?

# %%
len(df["country"].unique())
# Out:
# 73

# %%
df_country = df.groupby("country")

# %%
df_country_number = pd.DataFrame(df_country.size().sort_values(ascending=False), 
                           columns=["number"])

# %%
df_country_number.head()
# Out:
#                 number
# country
# United States      742
# China              546
# India              154
# Germany             94
# United Kingdom      81

# %%
sns.barplot(x = df_country_number["number"][:10] , y = df_country_number.index[:10])
# Out:
# <Axes: xlabel='number', ylabel='country'>

# %% [markdown]
# ## Who are the Top 10 richest in the Turkey?

# %%
df_turkey = df[df["country"]=="Turkey"]

# %%
df_turkey["personName"].count()
# Out:
# np.int64(23)

# %%
df_turkey.head(10)
# Out:
#                personName   age  finalWorth                    category  \
# rank
# 601           Murat Ulker  63.0      4700.0             Food & Beverage
# 1292    Ferit Faik Sahenk  58.0      2400.0                 Diversified
# 1341         Erman Ilicak  54.0      2300.0  Construction & Engineering
# 1397         Filiz Sahenk  55.0      2200.0                 Diversified
# 1579       Sezai Bacaksiz  72.0      1900.0                 Diversified
# 1579        Nihat Ozdemir  72.0      1900.0                 Diversified
# 1645    Ibrahim Erdemoglu  59.0      1800.0               Manufacturing
# 1818  Semahat Sevim Arsel  93.0      1600.0                 Diversified
# 1929  Hamdi Akin & family  67.0      1500.0                 Diversified
# 1929          Ahmet Calik  64.0      1500.0                 Diversified
#
#      country gender
# rank
# 601   Turkey      M
# 1292  Turkey      M
# 1341  Turkey      M
# 1397  Turkey      F
# 1579  Turkey      M
# 1579  Turkey      M
# 1645  Turkey      M
# 1818  Turkey      F
# 1929  Turkey      M
# 1929  Turkey      M

# %%
sns.barplot(y=df_turkey["personName"][:10], x = df_turkey["finalWorth"][:10])
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %%
df_nepal = df[df["country"]=="Nepal"]

# %%
df_nepal["personName"].count()
# Out:
# np.int64(1)

# %%
df_nepal
# Out:
#            personName   age  finalWorth     category country gender
# rank
# 1929  Binod Chaudhary  66.0      1500.0  Diversified   Nepal      M

# %% [markdown]
# ## Which Industry has the most billionaires in it?

# %%
df["category"].unique()
# Out:
# <StringArray>
# [                'Automotive',                 'Technology',
#            'Fashion & Retail',      'Finance & Investments',
#                 'Diversified',      'Media & Entertainment',
#                     'Telecom',            'Food & Beverage',
#                   'Logistics',                'Real Estate',
#             'Metals & Mining',              'Manufacturing',
#          'Gambling & Casinos',                 'Healthcare',
#                     'Service',                     'Energy',
#  'Construction & Engineering',                     'Sports']
# Length: 18, dtype: str

# %%
##df["category"]=df["category"].apply(lambda x:x.replace(" ","")).\
  ##  apply(lambda x:x.replace("&","_"))

# %%
df["category"].unique()
# Out:
# <StringArray>
# [              'Automotive',               'Technology',
#            'Fashion_Retail',      'Finance_Investments',
#               'Diversified',      'Media_Entertainment',
#                   'Telecom',            'Food_Beverage',
#                 'Logistics',               'RealEstate',
#             'Metals_Mining',            'Manufacturing',
#          'Gambling_Casinos',               'Healthcare',
#                   'Service',                   'Energy',
#  'Construction_Engineering',                   'Sports']
# Length: 18, dtype: str

# %%
df_category = df.groupby("category").size()

# %%
df_category.head()
# Out:
# category
# Automotive                   66
# Construction_Engineering     45
# Diversified                 174
# Energy                       93
# Fashion_Retail              238
# dtype: int64

# %%
df_category = df_category.to_frame()

# %%
df_category.head()
# Out:
#                             0
# category
# Automotive                 66
# Construction_Engineering   45
# Diversified               174
# Energy                     93
# Fashion_Retail            238

# %%
df_category = df_category.rename(columns={0:"count"}).sort_values(by="count",
                                                                ascending=False)

# %%
df_category.head()
# Out:
#                      count
# category
# Finance_Investments    381
# Technology             332
# Manufacturing          319
# Fashion_Retail         238
# Healthcare             209

# %%
sns.barplot( x = df_category["count"][:10], y = df_category.index[:10])
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %% [markdown]
# ## The distribution of age

# %%
sns.histplot(df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ## The youngest billionaires

# %%
df_age = df.sort_values(by="age")
df_age
# Out:
#               personName    age  finalWorth             category  \
# rank
# 2190  Alexandra Andresen   25.0      1300.0          Diversified
# 1929         Wang Zelong   25.0      1500.0        Metals_Mining
# 1929    Pedro Franceschi   25.0      1500.0  Finance_Investments
# 2190  Katharina Andresen   26.0      1300.0          Diversified
# 1929   Henrique Dubugras   26.0      1500.0  Finance_Investments
# ...                  ...    ...         ...                  ...
# 622        Masatoshi Ito   97.0      4600.0       Fashion_Retail
# 1341       David Murdock   98.0      2300.0        Food_Beverage
# 163          Robert Kuok   98.0     11700.0          Diversified
# 1238      Charles Munger   98.0      2500.0  Finance_Investments
# 1645       George Joseph  100.0      1800.0  Finance_Investments
#
#             country gender
# rank
# 2190         Norway      F
# 1929          China      M
# 1929  United States      M
# 2190         Norway      F
# 1929  United States      M
# ...             ...    ...
# 622           Japan      M
# 1341  United States      M
# 163       Hong Kong      M
# 1238  United States      M
# 1645  United States      M
#
# [2568 rows x 6 columns]

# %%
sns.barplot(y=df_age["personName"][:10], x = df_age["age"][:10])
# Out:
# <Axes: xlabel='age', ylabel='personName'>
