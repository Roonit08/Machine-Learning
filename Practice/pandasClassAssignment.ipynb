# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#find total number of males and females 
#find total number of survived male and female
#find total number of dead male and female
#find total number of dead and survived persons
#find total number of person embarked form each position
#find null values in each column
#fill null values in age with mean age
#fill null values in embarked with mode
#drop cabin,name,ticket column permanently
#round off the values in fare column to 2 decimal places
#find max,min and average fare
#change 0 to dead and 1 to survived

# %%
(df.Sex=='male').sum()
# Out:
# np.int64(577)

# %%
(df.Sex=='female').sum()
# Out:
# np.int64(314)

# %%
((df.Sex=='male')&(df.Survived==1)).sum()
# Out:
# np.int64(109)

# %%
((df.Sex=='female')&(df.Survived==1)).sum()
# Out:
# np.int64(233)

# %%
((df.Sex=='male')&(df.Survived==0)).sum()
# Out:
# np.int64(468)

# %%
((df.Sex=='female')&(df.Survived==0)).sum()
# Out:
# np.int64(81)

# %%
(df.Survived==1).sum()
# Out:
# np.int64(342)

# %%
(df.Survived==0).sum()
# Out:
# np.int64(549)

# %%
(df.Embarked=='S').sum()
# Out:
# np.int64(644)

# %%
(df.Embarked=='Q').sum()
# Out:
# np.int64(77)

# %%
df.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Age.fillna(mean_age , inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9568\4086637280.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Age.fillna(mean_age , inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Embarked.isnull().sum()
# Out:
# np.int64(2)

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
embarked_mode=df.Embarked.mode()[0]

# %%
embarked_mode
# Out:
# 'S'

# %%
df.Embarked.fillna(embarked_mode,inplace =True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9568\98864588.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Embarked.fillna(embarked_mode,inplace =True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Embarked.isnull().sum()
# Out:
# np.int64(0)

# %%
df.drop('column_name', axis=1, inplace=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('Name', axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female  29.7      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Embarked
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# 3              113803  53.1000        S
# ...

# %%
df.drop('Ticket', axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  29.7      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
new_fare=round(df['Fare'],2)

# %%
new_fare
# Out:
# 0       7.25
# 1      71.28
# 2       7.92
# 3      53.10
# 4       8.05
#        ...
# 886    13.00
# 887    30.00
# 888    23.45
# 889    30.00
# 890     7.75
# Name: Fare, Length: 891, dtype: float64

# %%
df.Fare.max()
# Out:
# 512.3292

# %%
df.Fare.min()
# Out:
# 0.0

# %%
df.Fare.mean()
# Out:
# np.float64(32.204207968574636)

# %%
# Out:
#      PassengerId  Survived  Pclass    Sex    Age  SibSp  Parch   Fare  \
# 0          False     False   False  False  False  False  False  False
# 1          False     False   False  False  False  False  False  False
# 2          False     False   False  False  False  False  False  False
# 3          False     False   False  False  False  False  False  False
# 4          False     False   False  False  False  False  False  False
# ..           ...       ...     ...    ...    ...    ...    ...    ...
# 886        False     False   False  False  False  False  False  False
# 887        False     False   False  False  False  False  False  False
# 888        False     False   False  False  False  False  False  False
# 889        False     False   False  False  False  False  False  False
# 890        False     False   False  False  False  False  False  False
#
#      Embarked
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 886     False
# ...

# %%
df.isnull().sum() #done after filling values in upper column so 0 is null(ram updated)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['Survived'] = df['Survived'].replace({0: 'dead', 1: 'survived'})

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1      dead       3    male  22.0      1      0   7.2500
# 1              2  survived       1  female  38.0      1      0  71.2833
# 2              3  survived       3  female  26.0      0      0   7.9250
# 3              4  survived       1  female  35.0      1      0  53.1000
# 4              5      dead       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887      dead       2    male  27.0      0      0  13.0000
# 887          888  survived       1  female  19.0      0      0  30.0000
# 888          889      dead       3  female  29.7      1      2  23.4500
# 889          890  survived       1    male  26.0      0      0  30.0000
# 890          891      dead       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...
