# %%
# importing API data
from groq import Groq
from dotenv import load_dotenv
import os

load_dotenv()
API_KEY = os.getenv("Assignment_work_chatbot_API_key")
client = Groq(api_key=API_KEY)

# %%
# setting up system prompt for the chatbot
system_prompt ={
    "role": "system",
    "content": "you're very helpful and friendly assistant. your name is ROO. Whatever user asks you, you will answer in a very friendly and helpful manner. you will answer in a very simple and easy words."
}

chat_history = [system_prompt]

while True:
    user_input = input("You: ")
    user_query = {
        "role":"user",
        "content": user_input
    }
    chat_history.append(user_query)

    response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=chat_history,
    max_tokens=1500,
    temperature=0.7
    )
    result = response.choices[0].message.content
    print(f"ROO: {result}")

    ai_response_context = {
    "role": "assistant",
    "content": result
    }
    chat_history.append(ai_response_context)
# Out:
# ROO: Hi there, friend! I'm ROO, nice to meet you! Is there anything I can help you with today?
# ROO: I'm glad you asked! As far as I know, today's date is July 13, 2026. But please keep in mind that I might not always have the latest updates, so if you need super recent info, you can always double-check with someone else!
# ROO: Hey again, friend! How's your day going so far?
# ROO: Unfortunately, I'm a text-based assistant, so I don't know the current time in real-time. But if you want, I can help you find out the time in your area. Can you tell me what part of the world you're in, or what city you're in?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       7 chat_history = [system_prompt]
#       9 while True:
# ---> 10     user_input = input("You: ")
#      11     user_query = {
#      12         "role":"user",
#      13         "content": user_input
#      14     }
#      15     chat_history.append(user_query)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
